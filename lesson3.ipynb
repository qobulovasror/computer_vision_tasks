# %%
# Robert
import random
from PIL import Image, ImageDraw
import math
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

image = Image.open("img3.tif") #Открываем изображение. 

width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 


imgnew  = Image.new( mode = "L", size = (width, height) )
imgnew2  = Image.new( mode = "L", size = (width, height) )

pix = image.load()

imgnewpix=imgnew.load()
imgnewpix2=imgnew2.load()

filtr=np.array([
    [-1,-2,-1],
    [0,0,0],
    [1,2,1]
], dtype=np.int8)

filtr1=np.array([[-1,0,1],[-2,0,2],[-1,0,1]], dtype=np.int8)
#filtr=np.array([[1,1,1],[1,-8,1],[1,1,1]], dtype=np.int8)

filtrsum=np.sum(filtr)
print(filtr)
for i in range(1,width-2):
    for j in range(1,height-2):
        imgnewpix[i,j]=0
        if (pix[i, j-1] == 0 and  pix[i, j+1] == 0 ) or (pix[i+1, j] == 0 and  pix[i, j+1] == 0 ) or (pix[i-1, j] == 0 and  pix[i, j+1] == 0 ) or (pix[i+1, j] == 0 and  pix[i, j+1] == 0 ) :
            imgnewpix[i,j]=255
        else:
            imgnewpix[i,j]=0
            # imgnewpix[i,j]=int(abs(255-pix[i,j]))
            # imgnewpix[i,j]=int(abs(0-pix[i,j]))

for i in range(0,width):
    for j in range(0,height):
        imgnewpix2[i,j]=int(abs(pix[i, j]-imgnewpix[i,j]))


fig = plt.figure(figsize=(10, 7))

rows, columns=(1,3)


fig.add_subplot(rows, columns, 1) 
# showing image 
plt.imshow(image,cmap='gray') 
plt.axis('off') 
plt.title("Berilgan")

fig.add_subplot(rows, columns, 2) 
# showing image 
plt.imshow(imgnew,cmap='gray') 
plt.axis('off') 
plt.title("Ishlangan")

fig.add_subplot(rows, columns, 3) 
# showing image 
plt.imshow(imgnew2,cmap='gray') 
plt.axis('off') 
plt.title("Ishlangan")


print("Tugadi")
# Out:
# [[-1 -2 -1]
#  [ 0  0  0]
#  [ 1  2  1]]
# Tugadi

# %%
import cv2 as cv
import sys
img = cv.imread(cv.samples.findFile("img2.jpg"))
if img is None:
    sys.exit("Could not read the image.")
cv.imshow("Display window", img)
k = cv.waitKey(0)
if k == ord("s"):
    cv.imwrite("starry_night.png", img)

# %%
# Robert
import random
from PIL import Image, ImageDraw #Подключим необходимые библиотеки. 
import math

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np


#mode = int(input('mode:')) #Считываем номер преобразования. 
image = Image.open("img3.tif") #Открываем изображение. 

width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 


imgnew  = Image.new( mode = "L", size = (width, height) )
dark_image_grey_fourier = np.fft.fftshift(np.fft.fft2(image))

dark_image_grey_fourier = 10*np.log(np.abs(dark_image_grey_fourier))
plt.subplot(121),plt.imshow(image, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dark_image_grey_fourier, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# Robert
import random
from PIL import Image, ImageDraw #Подключим необходимые библиотеки. 
import math

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np


#mode = int(input('mode:')) #Считываем номер преобразования. 
image = Image.open("img4.tif") #Открываем изображение. 

width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 


imgnew  = Image.new( mode = "L", size = (width, height) )
dark_image_grey_fourier = np.fft.fftshift(np.fft.fft2(image))

dark_image_grey_fourier = 10*np.log(np.abs(dark_image_grey_fourier))
plt.subplot(121),plt.imshow(image, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dark_image_grey_fourier, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# C:\Users\Asror Qobulov\AppData\Local\Temp\ipykernel_2300\3428437961.py:22: RuntimeWarning: divide by zero encountered in log
#   dark_image_grey_fourier = 10*np.log(np.abs(dark_image_grey_fourier))

# %%
# Battervort past chastotali tasvirlarga ishlov berish
import cv2
import numpy as np
import matplotlib.pyplot as plt


# Robert
import random
from PIL import Image, ImageDraw #Подключим необходимые библиотеки. 
import math

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np


#mode = int(input('mode:')) #Считываем номер преобразования. 
f = Image.open("img4.tif") #Открываем изображение. 
# original image
#f = cv2.imread("/Users/alisher/Desktop/DIP3E_Original_Images_CH04/Fig0429(a)(blown_ic).tif",0)

fig = plt.figure(figsize=(10, 10))

rows, columns=(4,3)

fig.add_subplot(rows, columns, 1) 

plt.imshow(f, cmap='gray')
plt.axis('off')
plt.title("Berilgan tasvir")



# image in frequency domain
F = np.fft.fft2(f)

fig.add_subplot(rows, columns,2) 
plt.imshow(np.log1p(np.abs(F)), 
           cmap='gray')
plt.axis('off')
plt.title("Tasvir spektri")

fig.add_subplot(rows, columns, 3) 
Fshift = np.fft.fftshift(F)
plt.imshow(np.log1p(np.abs(Fshift)), 
           cmap='gray')
plt.axis('off')
plt.title("Tasvir spektrini o`rtachalashtirish")

# Filter: Low pass filter
#M,N = f.shape

M = image.size[1] #Определяем ширину. 
N = image.size[0] #Определяем высоту. 


H = np.zeros((M,N), dtype=np.float32)

D0 = 50
n=1
for u in range(M):
    for v in range(N):
        D = np.sqrt((u-M/2)**2 + (v-N/2)**2)
        H[u,v] = 1/(1+(D/D0)**(2*n))
        

fig.add_subplot(rows, columns, 4) 
plt.imshow(H, cmap='gray')
plt.axis('off')
plt.title("Filtr tasviri")

# Ideal Low Pass Filtering
Gshift = Fshift * H

fig.add_subplot(rows, columns, 5) 
plt.imshow(np.log1p(np.abs(Gshift)), 
           cmap='gray')
plt.axis('off')
plt.title("Tasvirga filtr  ko`paytmasi tasviri")

# Inverse Fourier Transform
G = np.fft.ifftshift(Gshift)

fig.add_subplot(rows, columns, 6) 
plt.imshow(np.log1p(np.abs(G)), 
           cmap='gray')
plt.axis('off')
plt.title("O`rtachalashtirilgan tasvir")

g = np.abs(np.fft.ifft2(G))

fig.add_subplot(rows, columns, 7) 
plt.imshow(g, cmap='gray')
plt.axis('off')
plt.title("Ishlov berilgan tasvir")


# Filter: High pass filter
H = 1 - H
fig.add_subplot(rows, columns, 8)
plt.imshow(H, cmap='gray')
plt.axis('off')
plt.title("Filtr inkor tasviri")

# Ideal High Pass Filtering
Gshift = Fshift * H

fig.add_subplot(rows, columns, 9) 
plt.imshow(np.log1p(np.abs(Gshift)), 
           cmap='gray')
plt.axis('off')
plt.title("Tasvirga filtr  ko`paytmasi tasviri")

# Inverse Fourier Transform
G = np.fft.ifftshift(Gshift)
fig.add_subplot(rows, columns, 10) 
plt.imshow(np.log1p(np.abs(G)), 
           cmap='gray')
plt.axis('off')
plt.title("O`rtachalashtirilgan tasvir")

fig.add_subplot(rows, columns, 11) 
g = np.abs(np.fft.ifft2(G))
plt.imshow(g, cmap='gray')
plt.axis('off')
plt.title("Inkor filtr bilan ishlov berilgan tasvir")
# Out:
# Text(0.5, 1.0, 'Inkor filtr bilan ishlov berilgan tasvir')

# %%
import random
from PIL import Image, ImageDraw #Подключим необходимые библиотеки. 
import math

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
import numpy as np
import cv2
import time

cap = cv2.VideoCapture(0)
while(cap.isOpened()):

    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    ret, gb = cv2.threshold(gray,128,255,cv2.THRESH_BINARY)

    gb = cv2.bitwise_not(gb)

    contour,hier = cv2.findContours(gb,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)

    for cnt in contour:
        cv2.drawContours(gb,[cnt],0,255,-1)
    gray = cv2.bitwise_not(gb)

    cv2.drawContours(gray,contour,-1,(0,255,0),3)

    cv2.imshow('test', gray)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load grayscale image
gray_img = cv2.imread('img.tif', cv2.IMREAD_GRAYSCALE)

# Convert grayscale to RGB
rgb_img = cv2.merge((gray_img,)*3)

# Display RGB image
cv2.imshow('RGB Image', rgb_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Create random color image
image = (np.random.standard_normal([200,200,3]) * 255).astype(np.uint8)

# Convert to grayscale (1 channel)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Merge channels to create color image (3 channels)
gray_three = cv2.merge([gray,gray,gray])

# Fill a contour on both the single channel and three channel image
contour = np.array([[10,10], [190, 10], [190, 80], [10, 80]])
cv2.fillPoly(gray, [contour], [36,255,12])
cv2.fillPoly(gray_three, [contour], [36,255,12])

cv2.imshow('image', image)
cv2.imshow('gray', gray)
cv2.imshow('gray_three', gray_three)
cv2.waitKey()
# Out:
# -1

# %%
#mode = int(input('mode:')) #Считываем номер преобразования. 
# image = Image.open("/Users/alisher/Desktop/DIP3E_Original_Images_CH03/Fig0335(a)(ckt_board_saltpep_prob_pt05).tif") #Открываем изображение. 
image = Image.open("img.tif")
width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 


imgnew  = Image.new( mode = "L", size = (width, height) )

pix = image.load() #Выгружаем значения пикселей.

imgnewpix=imgnew.load()

filtr=np.array([1,1,1,1,1,1,1,1,1], dtype=np.int32)
filtrsum=np.sum(filtr)
print()
print(filtr[8])
for s in range(3):
    for t in range(3):
        print(s*3+t, end=", ")            
for i in range(1,width-2):
    for j in range(1, height-2):
        
        
        for s in range(3):
            for t in range(3):
                mediana[s*3+t]=pix[i+s,j+t]
        #print(mediana)
        #mediana=np.max(mediana)
        #print(mediana,"chiqdi")
        imgnewpix[i,j]=int(np.max(mediana))
fig = plt.figure(figsize=(10, 7))

rows, columns=(1,2)

fig.add_subplot(rows, columns, 1) 
  
# showing image 
plt.imshow(imgnew,cmap='gray') 
plt.axis('off') 
plt.title("Ishlangan")


fig.add_subplot(rows, columns, 2) 
  
# showing image 
plt.imshow(image,cmap='gray') 
plt.axis('off') 
plt.title("Berilgan")


print("Tugadi")
# Out:
# 1
# 0, 1, 2, 3, 4, 5, 6, 7, 8, Tugadi

# %%
# Robert
import random
from PIL import Image, ImageDraw #Подключим необходимые библиотеки. 
import math

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np


#mode = int(input('mode:')) #Считываем номер преобразования. 
image = Image.open("img3.tif") #Открываем изображение. 

width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 


imgnew  = Image.new( mode = "L", size = (width, height) )

pix = image.load() #Выгружаем значения пикселей.

imgnewpix=imgnew.load()

filtr=np.array([[-1,-2,-1],[0,0,0],[1,2,1]], dtype=np.int8)

filtr1=np.array([[-1,0,1],[-2,0,2],[-1,0,1]], dtype=np.int8)

#filtr=np.array([[1,1,1],[1,-8,1],[1,1,1]], dtype=np.int8)
filtrsum=np.sum(filtr)
print()
print(filtr)
for i in range(1,width-2):
    for j in range(1,height-2):
        imgnewpix[i,j]=0
        imgnewpix[i,j]=int(((pix[i+1,j+1]-pix[i,j])**2+abs(pix[i,j+1]-pix[i+1,j])**2)**1/2)



fig = plt.figure(figsize=(10, 7))

rows, columns=(1,2)




fig.add_subplot(rows, columns, 1) 
# showing image 
plt.imshow(image,cmap='gray') 
plt.axis('off') 
plt.title("Berilgan")


print("Tugadi")
# Out:
# [[-1 -2 -1]
#  [ 0  0  0]
#  [ 1  2  1]]
# Tugadi
